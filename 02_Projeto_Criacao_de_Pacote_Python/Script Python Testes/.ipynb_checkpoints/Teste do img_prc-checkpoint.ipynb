# %%
from img_prc.ut import chm, plotar
from img_prc.prc import comb, trns

# %%
img1 = chm.ler_img("C:/DIO_DIVEST/DataScience_Unimed-BH/02_Projeto_Criação_de_Pacote_Python/IMAGENS/289183941_5018883628220359_3836290341731603074_n.jpg")
img2 = chm.ler_img("C:/DIO_DIVEST/DataScience_Unimed-BH/02_Projeto_Criação_de_Pacote_Python/IMAGENS/1.jpg")

# %%
plotar.plot_img(img1)
plotar.plot_img(img2)

# %%
imgr = comb.trnsf_hist(img1, img2)
plotar.plot_resultado(img1, img2, imgr)
chm.slv_img(imgr, "C:/DIO_DIVEST/DataScience_Unimed-BH/02_Projeto_Criação_de_Pacote_Python/IMAGENS/Result.jpg")

# %%
img1 = chm.ler_img("C:/DIO_DIVEST/DataScience_Unimed-BH/02_Projeto_Criação_de_Pacote_Python/IMAGENS/2.jpg")
img2 = chm.ler_img("C:/DIO_DIVEST/DataScience_Unimed-BH/02_Projeto_Criação_de_Pacote_Python/IMAGENS/toucan-g789ef0f69_1280.jpg")

# %%
plotar.plot_img(img1)
plotar.plot_img(img2)

# %%
imgr = comb.trnsf_hist(img1, img2)
plotar.plot_resultado(img1, img2, imgr)
chm.slv_img(imgr, "C:/DIO_DIVEST/DataScience_Unimed-BH/02_Projeto_Criação_de_Pacote_Python/IMAGENS/Result2.jpg")
